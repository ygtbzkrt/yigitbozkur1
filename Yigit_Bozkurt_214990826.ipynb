# %%
from __future__ import print_function, division

import nsfg
pres= nsfg.ReadFemPreg()

# %%
pres.columns
pres.head(20)
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 13563   12547         2        NaN        NaN       NaN       NaN       6.0
# 13564   12547         3        NaN        NaN       NaN       NaN       6.0
# 13565   12550         1        NaN        NaN       NaN       NaN       6.0
# 13566   12551         1        NaN        NaN       NaN       NaN       5.0
# 13567   12554         1        NaN        NaN       NaN       NaN       3.0
# 13568   12554         2        NaN        NaN       NaN       NaN       4.0
# 13569   12556         1        NaN        NaN       NaN       NaN       6.0
# 13570   12556         2        NaN        NaN       NaN       NaN       6.0
# 13571   12556         3        NaN        NaN       NaN       NaN       6.0
# 13572   12556         4        NaN        NaN       NaN       NaN       6.0
# 13573   12561         1        NaN        NaN       NaN       NaN       6.0
# ...

# %%
pres.tail(30)
# Out:
#        caseid  pregordr  howpreg_n  howpreg_p  moscurrp  nowprgdk  pregend1  \
# 13563   12547         2        NaN        NaN       NaN       NaN       6.0
# 13564   12547         3        NaN        NaN       NaN       NaN       6.0
# 13565   12550         1        NaN        NaN       NaN       NaN       6.0
# 13566   12551         1        NaN        NaN       NaN       NaN       5.0
# 13567   12554         1        NaN        NaN       NaN       NaN       3.0
# 13568   12554         2        NaN        NaN       NaN       NaN       4.0
# 13569   12556         1        NaN        NaN       NaN       NaN       6.0
# 13570   12556         2        NaN        NaN       NaN       NaN       6.0
# 13571   12556         3        NaN        NaN       NaN       NaN       6.0
# 13572   12556         4        NaN        NaN       NaN       NaN       6.0
# 13573   12561         1        NaN        NaN       NaN       NaN       6.0
# ...

# %%
len(pres.columns)
# Out:
# 244

# %%
len(pres)
# Out:
# 13593

# %%
print ("There are " + str(len(pres)) + " rows and "+ str(len(pres.columns))+ " columns.")
# Out:
# There are 13593 rows and 244 columns.

# %%
pres["agescrn"]
# Out:
# 0        44
# 1        44
# 2        20
# 3        20
# 4        20
# 5        40
# 6        40
# 7        40
# 8        39
# 9        39
# 10       40
# 11       36
# 12       36
# 13       36
# 14       32
# 15       32
# 16       32
# 17       42
# 18       42
# 19       35
# 20       35
# 21       42
# 22       42
# 23       35
# 24       35
# 25       35
# 26       39
# 27       44
# 28       44
# 29       44
#          ..
# 13563    32
# 13564    32
# 13565    20
# 13566    38
# 13567    32
# 13568    32
# 13569    42
# 13570    42
# 13571    42
# 13572    42
# 13573    44
# 13574    44
# 13575    33
# 13576    34
# 13577    34
# 13578    27
# 13579    27
# 13580    35
# 13581    35
# 13582    35
# 13583    31
# 13584    31
# 13585    37
# 13586    37
# 13587    37
# 13588    37
# 13589    37
# 13590    37
# 13591    37
# 13592    37
# Name: agescrn, dtype: int64

# %%
print(pres.agescrn.min())
# Out:
# 15

# %%
print(pres.agescrn.max())
# Out:
# 44

# %%
pregnent= pres.prglngth

pregnent[2298]
# Out:
# 39

# %%
avg = pres.prglngth[pres.agescrn<=25]
avg.mean()
# Out:
# 28.271573604060915

# %%
maximum=pres.prglngth[pres.agescrn.max()]
maximum.mean()
# Out:
# 39.0
